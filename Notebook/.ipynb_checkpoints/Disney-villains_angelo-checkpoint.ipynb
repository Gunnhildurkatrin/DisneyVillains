# %% [markdown]
# ### Overview of the notebook
#
# * [Motivation](#chapter1)
#
# * [Basic statistics](#chapter2)
#
# * [Basic statistics](#chapter3)
#
# * [Discussion](#chapter4)
#
# * [Contributions](#chapter5)

# %% [markdown]
# ### Motivation <a class="anchor" id="chapter1"></a>

# %% [markdown]
# ### Basic statistics <a class="anchor" id="chapter2"></a>

# %%
from tqdm.notebook import tqdm
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

import urllib.request
import json
import re
import os
import collections

from fa2 import ForceAtlas2
from matplotlib.lines import Line2D

# %%
characters_df = pd.read_csv('name_of_villains_4ang.csv', sep = ';')

# %%
# characters_df[~characters_df.name_of_villains.str.contains(":")]
# This line has to run if we aree in Windows environment
# Out:
#       name_of_villains
# 0               A.I.M.
# 1            A.J. Arno
# 2             Abdullah
# 3     Abis Mal's Thugs
# 4          Abomination
# ...                ...
# 2765            Zoster
# 2766         Zurg Bots
# 2767      Emperor Zurg
# 2768             Zutho
# 2769             Zzzax
#
# [2770 rows x 1 columns]

# %%
'''
# Get description for all villains
def get_description(name):
    baseurl = "https://disney.fandom.com/api.php?"
    action = "action=query"
    title = "titles=" + name
    content = "prop=revisions&rvprop=content&rvslots=*"
    dataformat ="format=json"
    query = "{}{}&{}&{}&{}".format(baseurl, action, content, title, dataformat)
    
    wikiresponse = urllib.request.urlopen(query)
    wikidata = wikiresponse.read()
    wikitext = wikidata.decode('utf-8')
    wikijson = json.loads(wikitext)
    
    #page id check
    page_ids = list(wikijson['query']['pages'].keys())
    #get description
    description = wikijson['query']['pages'][page_ids[0]]['revisions'][0]['slots']['main']['*']
    return description
    '''

# %%
# Get the path for the folder that we keep the descriptions in 
'''
script_path = os.getcwd()
folder = 'Villains2/'
path = os.path.join(script_path,folder)
'''

# %%
# Load the description for all the villains into a txt file
'''
exceptions = []
for name in tqdm(list(characters_df['name_of_villains'].values)):
    try:
        villains_description = get_description(name.replace(' ','_'))
        with open(path + name + '.txt', 'w') as file:
            json.dump(villains_description, file)
    except:
        print(name)
        exceptions.append(name)
'''

# %%
# Get universes in the dataframe

# %%
def get_universe(characters_df):
    script_path = os.getcwd()
    folder = 'Villains2/'
    path = os.path.join(script_path,folder)
    
    universe_pattern = ['\[\[Category:(Marvel) Cinematic Universe characters\]\]',
                        '\[\[Category:(Marvel) Comics\]\]',
                        '\[\[Category:(Marvel) Comics characters\]\]',
                        '\[\[Category:(Pixar) characters\]\]',
                        '\[\[Category:(Disney) characters\]\]',
                        '\[\[Category:(Star Wars) characters\]\]',
                        '\[\[Category:(Star Wars) villains\]\]']

    
    universes = []
    for char in characters_df.name_of_villains.values:
        # open the description files
        with open(path + char + '.txt', 'r') as f:
            node_description = f.read()
        
        find_universes = []
        for p in universe_pattern:
            find_universes += re.findall(p, node_description)
            
        for univ in find_universes:
            universes.append((char, univ))
            

    return universes

# %%
universes = get_universe(characters_df)

# %%
df = pd.DataFrame(set(universes))

# %%
df['name_of_villains'] = df[0]
del df[0]
df['Universe'] = df[1]
del df[1]

# %%
df_villains = pd.merge(characters_df, df, on='name_of_villains', how='left')
df_villains = df_villains.fillna('N/A') # N/A means not applicable, suits better for this case

# %%
len(df_villains)
# Out:
# 2779

# %%
df_villains.groupby('Universe').count()
# Out:
#            name_of_villains
# Universe
# Disney                 1984
# Marvel                  284
# N/A                     330
# Pixar                    94
# Star Wars                87

# %%
#check if there are characters in multiple universes
doubles = df_villains[df_villains.duplicated(subset=['name_of_villains'], keep=False)]
doubles
# Out:
#             name_of_villains Universe
# 471                   Cobweb    Pixar
# 472                   Cobweb   Disney
# 640                  Dracula   Marvel
# 641                  Dracula   Disney
# 645                  Dragons   Marvel
# 646                  Dragons   Disney
# 647                  Dragons    Pixar
# 725          Ercole Visconti    Pixar
# 726          Ercole Visconti   Disney
# 856   Frankenstein's Monster   Marvel
# 857   Frankenstein's Monster   Disney
# 1035                   Grubs   Disney
# 1036                   Grubs    Pixar
# 1750                   Nazis   Marvel
# 1751                   Nazis   Disney
# 2553                Vampires   Marvel
# 2554                Vampires   Disney

# %% [markdown]
# #### we have few villains that belong to multiple uniiverses, we need to delete their doubles

# %%
# we sort them in a way that din´sney comes first and then delete the duplicates of the first column
# this way the charcters will not belong to disney anymore
df_villains = df_villains.sort_values('Universe')
df_villains = df_villains.drop_duplicates(subset='name_of_villains', keep="last")

len(df_villains)
# Out:
# 2770

# %% [markdown]
# Now, they are as many as they should be

# %%
df_villains.groupby('Universe').count()
# Out:
#            name_of_villains
# Universe
# Disney                 1976
# Marvel                  283
# N/A                     330
# Pixar                    94
# Star Wars                87

# %%
# Get the quotes in the DataFrame

# %%
# Get the hyperlinks
def get_hyperlinks(df_villains):
    script_path = os.getcwd()
    folder = 'Villains2/'
    path = os.path.join(script_path,folder)
    
    pattern = '\[\[(.*?)(?:\|.*?)?\]\]'
    links = []
    for char in df_villains.name_of_villains.values:
        # open the zelda description files
        with open(path + char + '.txt', 'r') as f:
            node_description = f.read()
    
        links_square = re.findall(pattern, node_description)
   
        # For pattern including square brackets  
        for name in links_square:
            # check if character is in the char list
            if name in df_villains.name_of_villains.values:
                links.append((char, name))
            else:
                continue
    return links

# %%
links = get_hyperlinks(df_villains)

# %%
len(links)
# Out:
# 11000

# %%
links
# Out:
# [('Komodo Dragon', "Makucha's Army"),
#  ('Komodo Dragon', 'Ora'),
#  ('Komodo Dragon', 'Chuluun'),
#  ('Komodo Dragon', 'Smun'),
#  ('Komodo Dragon', 'Jiona'),
#  ('Komodo Dragon', 'Fahari'),
#  ('Komodo Dragon', 'Ora'),
#  ('Komodo Dragon', "Makucha's Army"),
#  ('Komodo Dragon', 'Ora'),
#  ('Komodo Dragon', 'Makucha'),
#  ('Komodo Dragon', 'Chuluun'),
#  ('Komodo Dragon', 'Mama Binturong (character)'),
#  ('Thaddeus E. Klang', 'Kaa'),
#  ('Thaddeus E. Klang', 'Kaa'),
#  ('Kizin', 'Chatana'),
#  ('Kizin', 'Chancellor Esteban'),
#  ('Kizin', 'Chatana'),
#  ('Kismet', 'Felicia'),
#  ('Kip Killian', 'Carter and Trygstad'),
#  ('Kip Killian', 'Leonard Saber'),
#  ('The Sinister Sisters', 'Silas Sinister'),
#  ('King Zongo', 'Captain Hook'),
#  ('King Zongo', 'Mr. Smee'),
#  ('King Runeard', 'Earth Giants'),
#  ('King Runeard', 'The Nokk'),
#  ('King Runeard', 'Earth Giants'),
#  ('King Runeard', 'Percival C. McLeach'),
#  ('King Runeard', 'King Candy'),
#  ('King Runeard', 'Scar'),
#  ('King Runeard', 'Hades'),
#  ('King Runeard', 'Yokai'),
#  ('King Runeard', 'Lady Tremaine'),
#  ('King Andrias', 'Sasha Waybright'),
#  ('King Andrias', 'Captain Grime'),
#  ('King Andrias', 'Captain Grime'),
#  ('King Andrias', 'Frobots'),
#  ('King Andrias', 'Frobots'),
#  ('King Andrias', 'Sasha Waybright'),
#  ('King Andrias', 'Captain Grime'),
#  ('King Andrias', 'Sasha Waybright'),
#  ('Sirocco', 'Iago'),
#  ('Sirocco', 'Iago'),
#  ('The King', 'Gaston'),
#  ('The King', 'LeFou'),
#  ('The King', "Gaston's Buddies"),
#  ('Duff Killigan', 'Dr. Drakken'),
#  ('Duff Killigan', 'Shego'),
#  ('Duff Killigan', 'Monkey Fist'),
#  ('Duff Killigan', 'Shego'),
#  ('Duff Killigan', 'Dr. Drakken'),
#  ('Duff Killigan', 'Dr. Drakken'),
#  ('Duff Killigan', 'Shego'),
#  ('Duff Killigan', 'Monkey Fist'),
#  ('Duff Killigan', 'Hank Perkins'),
#  ('Duff Killigan', 'Dr. Drakken'),
#  ('Duff Killigan', 'Monkey Fist'),
#  ('Duff Killigan', 'Shego'),
#  ('The Skeleton King', 'Formless'),
#  ('The Skeleton King', 'Mandarin'),
#  ('The Skeleton King', 'Mandarin'),
#  ('The Skeleton King', 'Formless'),
#  ('The Skeleton King', 'Dark One Worm'),
#  ('The Skeleton King', 'Master Zan'),
#  ('The Skeleton King', 'Ma and Pa Sheenko'),
#  ('Killbot 86', 'Lord Hater'),
#  ('Killbot 86', 'Commander Peepers'),
#  ('Skeleton Pirate Captain', 'Captain Nathaniel Flint'),
#  ('Skeleton Pirate Captain', 'The Crew of the Wicked Wench'),
#  ('Skeleton Pirate Captain', 'The Crew of the Wicked Wench'),
#  ('Skeleton Pirate Captain', 'Hector Barbossa'),
#  ('Skeleton Pirate Captain', 'Hector Barbossa'),
#  ('Skeleton Pirate Captain', 'Blackbeard'),
#  ('Skeleton Pirate Captain', 'Hook Hand Pirate'),
#  ('Skeleton Pirate Captain', 'Redd'),
#  ('Skeleton Pirate Captain', 'Auctioneer'),
#  ('Skeleton Pirate Captain', 'Captain Gore'),
#  ('Kileem', 'Dominus Tusk'),
#  ('Kikimora', 'Hunter'),
#  ('Kikimora', 'Emperor Belos'),
#  ('Kikimora', 'Hunter'),
#  ('Khnum', 'Gods of Ancient Egypt'),
#  ('Khnum', 'Ra'),
#  ('Khnum', 'Bastet'),
#  ('Khnum', 'Gods of Ancient Egypt'),
#  ('Khartoum', 'Xerxes'),
#  ('Khartoum', 'Iago'),
#  ('Khartoum', 'Jafar'),
#  ('Shere Khan', 'Kaa'),
#  ('Shere Khan', 'Kaa'),
#  ('Shere Khan', 'Kaa'),
#  ('Shere Khan', 'Raja'),
#  ('Shere Khan', 'Air Pirates'),
#  ('Shere Khan', "Khan's Pilots"),
#  ('Shere Khan', 'Don Karnage'),
#  ('Shere Khan', 'Kaa'),
#  ('Shere Khan', 'Kaa'),
#  ('Shere Khan', 'Jafar'),
#  ('Shere Khan', 'William Boone'),
#  ('Shere Khan', 'Lt. John Wilkins'),
#  ('Shere Khan', 'Evie'),
#  ('Shere Khan', 'Maleficent'),
#  ('Shere Khan', 'Scar'),
#  ('Shere Khan', 'Don Karnage'),
#  ('Shere Khan', 'Kaa'),
#  ("Khan's Pilots", 'Air Pirates'),
#  ("Khan's Pilots", 'Don Karnage'),
#  ("Khan's Pilots", 'Douglas Benson'),
#  ('Captain Klegghorn', 'Lord Dragaunus'),
#  ('Aldrin Klordane', 'The Coachman'),
#  ('Aldrin Klordane', 'Fat Cat'),
#  ('Aldrin Klordane', 'Professor Norton Nimnul'),
#  ('Aldrin Klordane', 'Percy (Rescue Rangers)'),
#  ('Aldrin Klordane', 'Percy (Rescue Rangers)'),
#  ('Aldrin Klordane', 'Fat Cat'),
#  ('Aldrin Klordane', "Fat Cat's Gang"),
#  ('Aldrin Klordane', 'Professor Norton Nimnul'),
#  ('Aldrin Klordane', 'Fat Cat'),
#  ('Aldrin Klordane', 'Percy (Rescue Rangers)'),
#  ('Roger Klotz', 'Boomer Bledsoe'),
#  ('Roger Klotz', 'Willy White'),
#  ('Roger Klotz', 'Lamar Bone'),
#  ('Roger Klotz', 'Guy Graham'),
#  ('Roger Klotz', 'Percy Femur'),
#  ('Roger Klotz', 'Boomer Bledsoe'),
#  ('Roger Klotz', 'Willy White'),
#  ('Klutzy', 'Herbert P. Bear'),
#  ('Klutzy', 'Herbert P. Bear'),
#  ('Krinkle', 'A.J. Arno'),
#  ('Krinkle', 'Cookie'),
#  ('Krinkle', 'A.J. Arno'),
#  ('Silas', 'Aggro'),
#  ('Silas Sinister', 'The Sinister Sisters'),
#  ('John Silver', 'Scroop'),
#  ('John Silver', 'Admiral Evar'),
#  ('John Silver', 'Captain Hook'),
#  ('John Silver', 'Scroop'),
#  ('John Silver', 'Amos Slade'),
#  ('Kramer', 'Dr. Claw'),
#  ('Kramer', 'RoboGadget'),
#  ('Kramer', 'Dr. Claw'),
#  ('Kramer', 'RoboGadget'),
#  ('The Kraken', 'Kraken'),
#  ('Kraken', 'Davy Jones'),
#  ('Kraken', 'Davy Jones'),
#  ('Kraken', 'Cutler Beckett'),
#  ('Kraken', 'Pintel and Ragetti'),
#  ('Kraken', 'Rumplestiltskin'),
#  ('Khaka Peu Peu', 'Green Goblin'),
#  ('Kragthar', 'Lord Dominator'),
#  ('Krackenstein', 'Willem Viceroy'),
#  ('Dr. Kozak', 'Dr. Gwen Lichtman'),
#  ('Helga Sinclair', 'Lyle Tiberius Rourke'),
#  ('Helga Sinclair', 'Fidget the Bat'),
#  ('Kojak', 'Dr. Phillium Benedict'),
#  ('Kojak', 'Secret Service Look-Alike Agents'),
#  ('Kojak', 'Dr. Phillium Benedict'),
#  ('Kojak', 'Dr. Rosenthal'),
#  ('Koehler', 'Hector Barbossa'),
#  ('Koehler', "Bo'sun"),
#  ('Knights of Vengeance', 'Prince Phobos'),
#  ('Knights of Vengeance', 'Elyon Brown'),
#  ('Knights of Vengeance', 'Prince Phobos'),
#  ('Knights of Vengeance', 'Miranda'),
#  ('Knights of Vengeance', 'Raythor'),
#  ('Knights of Vengeance', 'Tracker'),
#  ('Neville Sinclair', 'Lothar'),
#  ('Neville Sinclair', 'Eddie Valentine'),
#  ('Neville Sinclair', 'Eddie Valentine'),
#  ('Neville Sinclair', 'Eddie Valentine'),
#  ('Neville Sinclair', 'Lothar'),
#  ('Knight Mare', 'Lord Hater'),
#  ('Knight Mare', 'Lord Dominator'),
#  ('Knave of Hearts', 'Red Queen'),
#  ('Knave of Hearts', 'Red Queen'),
#  ('Knave of Hearts', 'Red Queen'),
#  ('Knave of Hearts', 'Jabberwocky (2010)'),
#  ('Knave of Hearts', 'The Evil Queen'),
#  ('Knave of Hearts', 'Queen of Hearts'),
#  ('Knave of Hearts', 'Captain Hook'),
#  ('Kron', 'Carnotaurus'),
#  ('Kron', 'Bruton'),
#  ('Kron', 'Bruton'),
#  ('Kron', 'Carnotaurus'),
#  ('Kron', 'Bruton'),
#  ('Kenge', 'Scar'),
#  ('Kenge', 'Ushari'),
#  ('Kenge', 'Janja'),
#  ('Kenge', 'Cheezi'),
#  ('Kenge', 'Chungu'),
#  ('Kenge', 'Shupavu'),
#  ('Kenge', 'Janja'),
#  ('Kenge', 'Ushari'),
#  ('Kenge', 'Army of Scar'),
#  ('Kenge', 'Ushari'),
#  ('Kenge', 'Janja'),
#  ('Kenge', "Janja's Clan"),
#  ('Kenge', 'Cheezi'),
#  ('Kenge', 'Chungu'),
#  ('Kenge', 'Army of Scar'),
#  ('Kenge', 'Scar'),
#  ('Kenge', 'Ushari'),
#  ('Kenge', "Janja's Clan"),
#  ('Kenge', "Reirei's Pack"),
#  ('Mr. Smee', 'Captain Hook'),
#  ('Mr. Smee', 'Captain Hook'),
#  ('Mr. Smee', 'Sharky and Bones'),
#  ('Mr. Smee', 'Pirate Crew (Peter Pan)'),
#  ('Mr. Smee', 'Vidia'),
#  ('Mr. Smee', 'Beatrice Le Beak'),
#  ('Mr. Smee', 'ShiverJack (character)'),
#  ('Mr. Smee', 'Lord Fathom'),
#  ('Mr. Smee', 'Shade the Shadow Pirate'),
#  ('Mr. Smee', 'Captain Hook'),
#  ('Mr. Smee', 'Captain Hook'),
#  ('Mr. Smee', 'Captain Hook'),
#  ('Mr. Smee', 'Pirate Crew (Peter Pan)'),
#  ('Mr. Smee', 'Sharky and Bones'),
#  ('Mr. Smee', 'Don Karnage'),
#  ('Mr. Smee', 'Captain Hook'),
#  ('Mr. Smee', 'Rumplestiltskin'),
#  ('Mr. Smee', 'Maleficent'),
#  ('Mr. Smee', 'Heartless'),
#  ('Smoke', 'Eradicus'),
#  ('Smoke', 'Mirrors'),
#  ('Smoke', 'Ultimoose'),
#  ('Smoke', 'Saranoia'),
#  ('Kaa', 'Shere Khan'),
#  ('Kaa', 'Shere Khan'),
#  ('Kaa', 'Jafar'),
#  ('Kaa', 'William Boone'),
#  ('Kaa', 'Maleficent'),
#  ('Kaa', 'Whitehood'),
#  ('Kaa', 'Shere Khan'),
#  ('Kaa', 'Sir Hiss'),
#  ('Ka-Hoo-Fu', 'Sarkus'),
#  ('Ka-Hoo-Fu', 'Sarkus'),
#  ('Smolder the Bear', 'Little Jimmy'),
#  ('Smolder the Bear', 'Quint'),
#  ('Smolder the Bear', 'Quint'),
#  ('Smolder the Bear', 'Little Jimmy'),
#  ('Smolder the Bear', 'Quint'),
#  ('Smolder the Bear', 'Quint'),
#  ('Julius', 'Pete'),
#  ('Julius', 'Pete'),
#  ('Julius', 'Doctor Frankenollie'),
#  ('Julius', 'Pete'),
#  ('Julius', 'Doctor Frankenollie'),
#  ('Julius', 'Riku'),
#  ('Juice-Lee', 'Fat Cat'),
#  ('Juice-Lee', 'Fat Cat'),
#  ('Juice-Lee', 'Fat Cat'),
#  ('Juice-Lee', "Fat Cat's Gang"),
#  ('Judge Doom', 'Toon'),
#  ('Judge Doom', 'Toon Patrol'),
#  ('Judge Doom', 'Toon Patrol'),
#  ('Judge Doom', 'Theodora the Wicked Witch of the West'),
#  ('Judge Doom', 'Man'),
#  ('Judge Doom', 'The Collector'),
#  ('Judge Doom', 'Toon'),
#  ('Judge Dimsdale De Vil', 'Cruella De Vil'),
#  ('Judge Dimsdale De Vil', 'Cruella De Vil'),
#  ('Judge Dimsdale De Vil', 'Cecil B. De Vil'),
#  ('Judge Dimsdale De Vil', 'P.H. De Vil'),
#  ('Judge Dimsdale De Vil', 'Ivy De Vil'),
#  ('Judge Dimsdale De Vil', 'Cruella De Vil'),
#  ('Judge Dimsdale De Vil', 'Cruella De Vil'),
#  ('Judge Dimsdale De Vil', 'Malevola De Vil'),
#  ('Josh (The Weekenders)', 'Laird Lambert'),
#  ('Dr. Screwball Jones', 'Ratigan'),
#  ('Dr. Screwball Jones', 'Night Mayor'),
#  ('Dr. Screwball Jones', 'Lord Hater'),
#  ('Dr. Screwball Jones', 'Commander Peepers'),
#  ('Dr. Screwball Jones', 'Lord Dominator'),
#  ('Dr. Screwball Jones', 'Lord Dominator'),
#  ('Dr. Screwball Jones', 'Lord Hater'),
#  ('Smun', 'Mama Binturong (character)'),
#  ('Smun', "Makucha's Army"),
#  ('Smun', 'Mama Binturong (character)'),
#  ('Smun', 'Makucha'),
#  ('Smun', 'Chuluun'),
#  ('Smun', 'Ora'),
#  ('Smun', 'Komodo Dragon'),
#  ('Smun', 'Mama Binturong (character)'),
#  ('Smun', 'Mama Binturong (character)'),
#  ('Smun', "Makucha's Army"),
#  ('Smun', 'Makucha'),
#  ('Smun', 'Chuluun'),
#  ('Smun', 'Ora'),
#  ('Smun', 'Mama Binturong (character)'),
#  ('Smun', 'Makucha'),
#  ('Smun', 'Chuluun'),
#  ('Smun', 'Ora'),
#  ('Smun', 'Fahari'),
#  ('Smun', 'Jiona'),
#  ('Kaia', 'Terra (Motorcity)'),
#  ('Kaia', 'Terra (Motorcity)'),
#  ('Kaia', 'Abraham Kane'),
#  ('Kaia', 'Terra (Motorcity)'),
#  ('Dr. Slug', 'Megavolt'),
#  ('Dr. Slug', 'Megavolt'),
#  ('Lord Kelvin', 'General Fang'),
#  ('Kelpie', 'Troll'),
#  ('Wizard Kelly', 'Sista Spice'),
#  ('Wizard Kelly', 'Little Wiz'),
#  ('Wizard Kelly', 'Little Wiz'),
#  ('Keller', 'General Tesler'),
#  ('Keller', 'Paige'),
#  ('Skeletons', 'The Grim Reaper'),
#  ('Skeletons', 'Grim Reaper'),
#  ('Skeletons', 'Pete'),
#  ('Keelhaul Pete', 'Pete'),
#  ('Keelhaul Pete', 'Captain Hook'),
#  ('Keelhaul Pete', 'Pete'),
#  ('Keelhaul Pete', 'Pete'),
#  ('Keelhaul Pete', 'Pete'),
#  ('Kazar', 'Mola Ram'),
#  ('Kazar', 'Hopper'),
#  ('Kazar', 'Blag'),
#  ('Kazar', 'Scab and Scraw'),
#  ('Kazar', 'Blag'),
#  ('Kazar', 'Scab and Scraw'),
#  ('Kazar', 'Blag'),
#  ('Kazar', 'Scab and Scraw'),
#  ('Kazar', 'Blag'),
#  ('Mr. Skinner', 'Cruella De Vil'),
#  ('Mr. Skinner', 'Jasper and Horace'),
#  ('Mr. Skinner', 'Jasper and Horace'),
#  ('Mr. Skinner', 'Jasper and Horace'),
#  ('Mr. Skinner', 'Cruella De Vil'),
#  ('Mr. Skinner', 'Jasper and Horace'),
#  ('Mr. Skinner', 'Alonzo'),
#  ('Mr. Skinner', 'Cruella De Vil'),
#  ('Mr. Skinner', 'Jasper and Horace'),
#  ('Mr. Skinner', 'Judge Doom'),
#  ('Slab', 'Duke (Goof Troop)'),
#  ('Carl Karl', 'Heinz Doofenshmirtz'),
#  ('Carl Karl', 'Heinz Doofenshmirtz'),
#  ('Carl Karl', 'Aloyse von Roddenstein'),
#  ('Carl Karl', 'Heinz Doofenshmirtz'),
#  ('John Slade', 'Alonzo Hawk'),
#  ('John Slade', 'Alonzo Hawk'),
#  ('Karasu Tengu', 'Baron Von Sheldgoose'),
#  ('Slaying Mantis', 'Willem Viceroy'),
#  ('Slaying Mantis', 'Hannibal McFist'),
#  ('Slickwell', 'Greylock the Grand'),
#  ('Alameda Slim', 'The Willie Brothers'),
#  ('Alameda Slim', 'Mr. Wesley'),
#  ('Alameda Slim', 'Rico'),
#  ('Alameda Slim', 'Mr. Wesley'),
#  ('Alameda Slim', 'Governor Ratcliffe'),
#  ('Slime Nega Duck', 'Negaduck'),
#  ('Kalabar', 'Luke (Halloweentown)'),
#  ('Joaquin Slowly', 'El Capitan'),
#  ('Amos Slade', 'Colonel Pierson'),
#  ('Amos Slade', 'Chief'),
#  ('Amos Slade', 'Chief'),
#  ('Amos Slade', 'Chief'),
#  ('Amos Slade', 'John Silver'),
#  ('Kronin', 'Organization (PKNA)'),
#  ('Kronin', 'The Raider'),
#  ('Kronin', 'Organization (PKNA)'),
#  ('Kronos', 'Titans'),
#  ('Kronos', 'Titans'),
#  ('Kronos', 'Hades'),
#  ('Kronos', 'Titans'),
#  ('Kronos', 'Hades'),
#  ('Kronos', 'Titans'),
#  ('Kronos', 'Hades'),
#  ('Kronos', 'Pain and Panic'),
#  ('Kronos', 'Pain and Panic'),
#  ('Kronos', 'Hades'),
#  ('Sheriff of Nottingham (1952 character)', 'Prince John (1952 character)'),
#  ('Sheriff of Nottingham (1952 character)', 'Prince John (1952 character)'),
#  ('Sheriff of Nottingham (1952 character)', 'Red Gill'),
#  ('Sheriff of Nottingham (1952 character)', "Prince John's Guards"),
#  ('Sheriff of Nottingham (1952 character)', "Prince John's Guards"),
#  ('Sheriff of Nottingham (1952 character)', 'Prince John (1952 character)'),
#  ('Lope de Aguirre', 'Prince Joachim'),
#  ('Ronald Longcape Jr.', 'Ronald Longcape Sr.'),
#  ('Long John Silver (Treasure Island)', 'John Silver'),
#  ('Long John Silver (Treasure Island)', 'Captain Hook'),
#  ('Long John Silver (Treasure Island)', 'Hades'),
#  ('Long John Silver (Treasure Island)', 'Hector Barbossa'),
#  ('Long John Silver (Treasure Island)', 'Jack the Monkey'),
#  ('Long John Silver (Treasure Island)', 'Blackbeard'),
#  ('Ace London', 'Don Karnage'),
#  ('Ace London', 'Air Pirates'),
#  ('Ace London', 'Don Karnage'),
#  ('Ace London', 'Air Pirates'),
#  ('Loki (Hercules)', 'Loki Laufeyson'),
#  ('Loki (Hercules)', 'Fenrir'),
#  ('Loki (Hercules)', 'Fenrir'),
#  ('Loca', 'Bianca'),
#  ('Loca', 'Alana Rivera'),
#  ('Loca', 'Alana Rivera'),
#  ('Loca', 'Bianca'),
#  ('Lobster Mobster and Da Shrimp', 'Glut the Shark'),
#  ('ShiverJack (character)', 'Captain Hook'),
#  ('ShiverJack (character)', 'Doctor Undergear'),
#  ('ShiverJack (character)', 'Captain Hook'),
#  ('ShiverJack (character)', 'Mr. Smee'),
#  ('ShiverJack (character)', 'Sharky and Bones'),
#  ('ShiverJack (character)', 'Captain Hook'),
#  ('Little Wiz', 'Wizard Kelly'),
#  ('Little Wiz', 'Wizard Kelly'),
#  ('Little Jimmy', 'Smolder the Bear'),
#  ('Little Jimmy', 'Smolder the Bear'),
#  ('Little Bits', 'Lord Hater'),
#  ('Liquidator', 'Hydro-Man'),
#  ('Liquidator', 'Fearsome Five'),
#  ('Liquidator', 'Negaduck'),
#  ('Liquidator', 'Megavolt'),
#  ('Liquidator', 'Quackerjack'),
#  ('Liquidator', 'Fearsome Five'),
#  ('Liquidator', 'Megavolt'),
#  ('Liquidator', 'Quackerjack'),
#  ('Liquidator', 'Negaduck'),
#  ('Liquidator', 'Fearsome Five'),
#  ('Liquidator', 'Negaduck'),
#  ('Liquidator', 'Quackerjack'),
#  ('Liquidator', 'Megavolt'),
#  ('Liquidator', 'Hydro-Man'),
#  ('Edward Lipsky', 'Dr. Drakken'),
#  ('Edward Lipsky', 'Dr. Drakken'),
#  ('Edward Lipsky', 'Shego'),
#  ('Edward Lipsky', 'Dr. Drakken'),
#  ('Bartholomew Lipsky', 'Dr. Drakken'),
#  ('Bartholomew Lipsky', 'Professor Dementor'),
#  ('Bartholomew Lipsky', 'Miss Go'),
#  ('Bartholomew Lipsky', 'Shego'),
#  ('Lioness', 'Outsiders'),
#  ('Lioness', 'Outsiders'),
#  ('Lioness', 'Zira'),
#  ('Lioness', 'Outsiders'),
#  ('Lioness', 'Vitani'),
#  ('Lioness', 'Nuka'),
#  ('Lioness', 'Zira'),
#  ('Lioness', 'Outsiders'),
#  ('Lioness', 'Zira'),
#  ('Lioness', 'Scar'),
#  ('Lioness', 'Nuka'),
#  ('Lord Felldrake Sheldgoose', 'Baron Von Sheldgoose'),
#  ('Lord Felldrake Sheldgoose', 'Leopold the Horrible'),
#  ('Lord Felldrake Sheldgoose', 'Baron Von Sheldgoose'),
#  ('Lord Felldrake Sheldgoose', 'Leopold the Horrible'),
#  ('Lord Felldrake Sheldgoose', 'Baron Von Sheldgoose'),
#  ('Lord Felldrake Sheldgoose', 'Leopold the Horrible'),
#  ('Lord Felldrake Sheldgoose', 'Baron Von Sheldgoose'),
#  ('Sheriff of Nottingham', 'Prince John'),
#  ('Sheriff of Nottingham', 'Sir Hiss'),
#  ('Sheriff of Nottingham', 'Trigger and Nutsy'),
#  ('Sheriff of Nottingham', 'Rhino Guards'),
#  ('Sheriff of Nottingham', 'Prince John'),
#  ('Sheriff of Nottingham', 'Wolf Arrowmen'),
#  ('Sheriff of Nottingham', 'Trigger and Nutsy'),
#  ('Sheriff of Nottingham', 'Sir Hiss'),
#  ('Sheriff of Nottingham', 'Prince John'),
#  ('Sheriff of Nottingham', 'Trigger and Nutsy'),
#  ('Sheriff of Nottingham', 'Rumplestiltskin'),
#  ('Sheriff of Nottingham', 'The Evil Queen'),
#  ('Sheriff of Nottingham', 'Hades'),
#  ('Sheriff of Nottingham', 'Prince John'),
#  ('Lothar', 'Neville Sinclair'),
#  ('Lothar', 'Neville Sinclair'),
#  ('Lothar', 'Eddie Valentine'),
#  ('Lothar', 'Neville Sinclair'),
#  ('Lothar', 'Neville Sinclair'),
#  ('Lothar', 'Neville Sinclair'),
#  ('Lothar', 'Eddie Valentine'),
#  ('Phineas Sharp', 'Hammerhead Hannigan'),
#  ('Phineas Sharp', 'Ammonia Pine'),
#  ('Phineas Sharp', 'Hammerhead Hannigan'),
#  ('Phineas Sharp', 'Anna Matronic'),
#  ('Phineas Sharp', 'Lilliput (Darkwing Duck)'),
#  ('Shaw', 'General Tesler'),
#  ('Luke and Tinker', 'Beauty Smith'),
#  ('Luke and Tinker', 'Beauty Smith'),
#  ('Luke (Halloweentown)', 'Kalabar'),
#  ("Ludo's army", 'Ludo'),
#  ("Ludo's army", 'Toffee'),
#  ("Ludo's army", 'Buff Frog'),
#  ("Ludo's army", 'Ludo'),
#  ("Ludo's army", 'Buff Frog'),
#  ("Ludo's army", 'Ludo'),
#  ("Ludo's army", 'Toffee'),
#  ("Ludo's army", 'Buff Frog'),
#  ('Ludo', 'Toffee'),
#  ('Ludo', 'Buff Frog'),
#  ('Ludo', 'Toffee'),
#  ('Ludo', 'Brittney Wong'),
#  ('Ludo', "Li'l Gideon"),
#  ('Ludo', 'Toffee'),
#  ('Ludo', 'Buff Frog'),
#  ('Ludo', 'Toffee'),
#  ('Ludo', 'King Candy'),
#  ('Ludo', 'Duke of Weselton'),
#  ('Shego', 'Dr. Drakken'),
#  ('Shego', 'Dr. Drakken'),
#  ('Shego', 'Dr. Drakken'),
#  ('Shego', 'Dr. Drakken'),
#  ('Shego', 'Dr. Drakken'),
#  ('Shego', 'Duff Killigan'),
#  ('Shego', 'DNAmy'),
#  ('Shego', 'Hank Perkins'),
#  ('Shego', 'Frugal Lucre'),
#  ('Shego', 'Monkey Fist'),
#  ('Shego', 'Dr. Drakken'),
#  ('Shego', 'Dr. Drakken'),
#  ('Shego', 'Jack Hench'),
#  ('Frugal Lucre', 'Dr. Drakken'),
#  ('Frugal Lucre', 'Dr. Drakken'),
#  ('Shepard', 'Prindle'),
#  ('Shepard', 'Quinn (The Love Bug)'),
#  ('Shepard', 'Prindle'),
#  ('Shepard', 'Quinn (The Love Bug)'),
#  ('Lucinda (Hannah Montana)', 'Oswald Granger'),
#  ('Lucinda (Hannah Montana)', 'Oswald Granger'),
#  ('Lucinda (Into the Woods)', 'Anastasia Tremaine'),
#  ('Lucinda (Into the Woods)', 'Florinda'),
#  ('Lucinda (Into the Woods)', 'Florinda'),
#  ('Lucinda (Into the Woods)', 'Witch (Into the Woods)'),
#  ('Lucinda (Into the Woods)', 'Florinda'),
#  ('Lucinda (Into the Woods)', 'Florinda'),
#  ('Lucinda (Into the Woods)', 'Lady Tremaine'),
#  ('Lucinda (Into the Woods)', 'Florinda'),
#  ('Lucinda (Into the Woods)', 'Anastasia Tremaine'),
#  ('Lucinda (Into the Woods)', 'Drizella Tremaine'),
#  ('Lucifer the Tough Cat', 'Lucifer'),
#  ('Lucifer', 'Lucifer the Tough Cat'),
#  ('Lucifer', 'Lady Tremaine'),
#  ('Lucifer', 'Drizella Tremaine'),
#  ('Lucifer', 'Anastasia Tremaine'),
#  ('Lucifer', 'Lady Tremaine'),
#  ('Lucifer', 'Lady Tremaine'),
#  ('Lucifer', 'Drizella Tremaine'),
#  ('Lucifer', 'Anastasia Tremaine'),
#  ('Lucifer', 'Lady Tremaine'),
#  ('Lucifer', 'Anastasia Tremaine'),
#  ('Lucifer', 'Drizella Tremaine'),
#  ('Lucifer', 'Lady Tremaine'),
#  ('Lucifer', 'Jafar'),
#  ('Lucifer', 'Lord Felldrake Sheldgoose'),
#  ('Lucifer', 'Carlos De Vil'),
#  ('Mina Loveberry', 'Ludo'),
#  ('Mina Loveberry', 'Tom Lucitor'),
#  ('Mina Loveberry', 'Maleficent'),
#  ('Mina Loveberry', 'Diablo'),
#  ("Lou (Chip 'n Dale Rescue Rangers)", "Bud (Chip 'n Dale)"),
#  ("Lou (Chip 'n Dale Rescue Rangers)", "Bud (Chip 'n Dale)"),
#  ("Lou (Chip 'n Dale Rescue Rangers)", "Bud (Chip 'n Dale)"),
#  ("Lou (Chip 'n Dale Rescue Rangers)", "Bud (Chip 'n Dale)"),
#  ("Lou (Chip 'n Dale Rescue Rangers)", "Bud (Chip 'n Dale)"),
#  ('Lily St. Regis', 'Rooster Hannigan'),
#  ('Lily St. Regis', 'Agatha Hannigan'),
#  ('Lily St. Regis', 'Rooster Hannigan'),
#  ('Lily St. Regis', 'Agatha Hannigan'),
#  ('Beatrice Le Beak', 'Fast Claw'),
#  ('Beatrice Le Beak', 'Captain Hook'),
#  ('Beatrice Le Beak', 'Mr. Smee'),
#  ('Beatrice Le Beak', 'Sharky and Bones'),
#  ('Beatrice Le Beak', 'Lord Fathom'),
#  ('Beatrice Le Beak', 'Fast Claw'),
#  ('Beatrice Le Beak', 'Captain Hook'),
#  ('Beatrice Le Beak', 'Fast Claw'),
#  ('Beatrice Le Beak', 'Mr. Smee'),
#  ('Beatrice Le Beak', 'Sharky and Bones'),
#  ('Beatrice Le Beak', 'Captain Hook'),
#  ('Beatrice Le Beak', 'Mr. Smee'),
#  ('Beatrice Le Beak', 'Sharky and Bones'),
#  ('Beatrice Le Beak', 'The Sea Witch'),
#  ('Erwin Lawson', 'Sid Phillips'),
#  ('Lawrence (The Princess and the Frog)', 'Mr. Smee'),
#  ('Lawrence (The Princess and the Frog)', 'Dr. Facilier'),
#  ('Lawrence (The Princess and the Frog)', 'Dr. Facilier'),
#  ('Lawrence (The Princess and the Frog)', 'Dr. Facilier'),
#  ('Lawrence (The Princess and the Frog)', 'Mr. Smee'),
#  ('Lawrence (The Princess and the Frog)',
#   "Facilier's Friends on the Other Side"),
#  ('Lawrence (The Princess and the Frog)', 'Hades'),
#  ('Lava Lizards', 'Baron Von Sheldgoose'),
#  ('Lava Lizards', 'Baron Von Sheldgoose'),
#  ('Lava Lizards', 'Baron Von Sheldgoose'),
#  ('Lava Lizards', 'Lord Felldrake Sheldgoose'),
#  ('Siege', 'Lord Dragaunus'),
#  ('Siege', 'Chameleon'),
#  ('Siege', 'Wraith'),
#  ('Siege', 'Chameleon'),
#  ('Siege', 'Wraith'),
#  ('Siege', 'Lord Dragaunus'),
#  ('Siegmund', 'Vampire'),
#  ('Siegmund', 'Viking'),
#  ('Lash (Sky High)', 'Penny Lent'),
#  ('Lash (Sky High)', 'Gwen Grayson'),
#  ('Lash (Sky High)', 'Gwen Grayson'),
#  ('Larry Willingham', 'Coach Barker'),
#  ('Larry Willingham', 'Buck Willingham'),
#  ('Larry Willingham', 'Buck Willingham'),
#  ('Larry Willingham', 'Buck Willingham'),
#  ('Larry Willingham', 'Coach Barker'),
#  ('The Siamese Twin Gang', 'Si and Am'),
#  ('Sierra McCool', 'Jennifer and Claudia'),
#  ('Sierra McCool', 'Jennifer and Claudia'),
#  ('Ladon', 'Echidna'),
#  ('Queen La', 'Leopard Men'),
#  ('Queen La', 'Leopard Men'),
#  ('Queen La', 'Kaj'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Heinz Doofenshmirtz'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Aloyse von Roddenstein'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Professor Bannister'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Dr. Bloodpudding'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Dr. Diminutive'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Aloyse von Roddenstein'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Heinz Doofenshmirtz'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Heinz Doofenshmirtz'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Heinz Doofenshmirtz'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Norm'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Heinz Doofenshmirtz'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Norm'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Heinz Doofenshmirtz'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Professor Bannister'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Dr. Bloodpudding'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Dr. Diminutive'),
#  ('L.C. Clench', 'X-S Tech'),
#  ('L.C. Clench', 'X-S Tech'),
#  ('L.C. Clench', 'X-S Tech'),
#  ('L.C. Clench', 'The Alien'),
#  ('Kumo', 'Eli Excelsior Pandarus'),
#  ('Kuala', 'Pirates (Swiss Family Robinson)'),
#  ('Kuala', 'Pirates (Swiss Family Robinson)'),
#  ('Kuala', 'Tiger (Swiss Family Robinson)'),
#  ('The Krylock Demon', 'Avemetrus'),
#  ('Davy Jones', 'Kraken'),
#  ('Davy Jones', 'Kraken'),
#  ('Davy Jones', 'Cutler Beckett'),
#  ('Davy Jones', 'Pirate Crew (Peter Pan)'),
#  ('Davy Jones', 'Mr. Smee'),
#  ('Davy Jones', 'Captain Hook'),
#  ('Davy Jones', 'Kraken'),
#  ('Davy Jones', 'Cutler Beckett'),
#  ('Davy Jones', 'Cutler Beckett'),
#  ('Davy Jones', 'Kraken'),
#  ('Davy Jones', 'Sao Feng'),
#  ('Davy Jones', 'Hector Barbossa'),
#  ('Davy Jones', 'Organization XIII'),
#  ('Davy Jones', 'Cutler Beckett'),
#  ('Davy Jones', 'Hook Hand Pirate'),
#  ('Davy Jones', 'Redd'),
#  ('Davy Jones', 'Auctioneer'),
#  ('Davy Jones', 'Blackbeard'),
#  ('Davy Jones', 'Pirate Robber'),
#  ('Davy Jones', 'The Pooped Pirate'),
#  ('Davy Jones', 'Blackbeard'),
#  ('Davy Jones', 'Jabba the Hutt'),
#  ('Davy Jones', 'The Phantom'),
#  ('Morgana le Fay', 'Morgan le Fay'),
#  ('Morgana le Fay', 'Maxim Horvath'),
#  ('Morgana le Fay', 'Abigail Williams'),
#  ('Morgana le Fay', 'Maxim Horvath'),
#  ('Morgana le Fay', 'Abigail Williams'),
#  ("Lil' Lightning", 'Cruella De Vil'),
#  ("Lil' Lightning", 'Jasper and Horace'),
#  ("Lil' Lightning", 'Cruella De Vil'),
#  ("Lil' Lightning", 'Jasper and Horace'),
#  ('Lieutenant Colonel Staquait', 'Jafar'),
#  ('Lieutenant Colonel Staquait', 'Scar'),
#  ('Lieutenant Colonel Staquait', 'Claude Frollo'),
#  ('Lieutenant Colonel Staquait', 'Jafar'),
#  ('Lieutenant Colonel Staquait', 'Scar'),
#  ('Lieutenant Colonel Staquait', 'Claude Frollo'),
#  ('Dr. Gwen Lichtman', 'Dr. Kozak'),
#  ("Li'l Gideon", 'Bill Cipher'),
#  ("Li'l Gideon", 'Bill Cipher'),
#  ("Li'l Gideon", 'Ghost-Eyes'),
#  ("Li'l Gideon", 'Bill Cipher'),
#  ("Li'l Gideon", 'Bill Cipher'),
#  ('Flint Shrubwood', 'Duke Igthorn'),
#  ('Flint Shrubwood', 'Duke Igthorn'),
#  ('Flint Shrubwood', 'Lady Bane'),
#  ('Flint Shrubwood', 'Princess Marie'),
#  ('Flint Shrubwood', 'Angelo Davini'),
#  ('Flint Shrubwood', 'The Hunter'),
#  ('Flint Shrubwood', 'Rotocelli'),
#  ('Flint Shrubwood', 'Marzipan'),
#  ('Flint Shrubwood', 'Lord Willoughby'),
#  ('Lesaro', 'Crew of the Silent Mary'),
#  ('Lesaro', 'Captain Salazar'),
#  ('Lesaro', 'Hector Barbossa'),
#  ('Lesaro', 'Captain Salazar'),
#  ('Lesaro', 'Captain Salazar'),
#  ('Lesaro', 'Captain Salazar'),
#  ('Lesaro', 'Crew of the Silent Mary'),
#  ('Les Camembert', 'Dr. Fusion'),
#  ('Les Camembert', 'Dr. Fusion'),
#  ('Le Sewer and Ratatouille', 'Maltese de Sade'),
#  ('Le Sewer and Ratatouille', 'Maltese de Sade'),
#  ('Le Sewer and Ratatouille', 'Maltese de Sade'),
#  ('Leroy Clones', 'Leroy'),
#  ('Leroy Clones', 'Leroy'),
#  ('Leroy Clones', 'Leroy'),
#  ('Leroy Clones', 'Leroy'),
#  ('Leroy Clones', 'Clone Troopers'),
#  ('Leopold the Horrible', 'Lord Felldrake Sheldgoose'),
#  ('Leopold the Horrible', 'Baron Von Sheldgoose'),
#  ('Leopold the Horrible', 'Lord Felldrake Sheldgoose'),
#  ('Leopold the Horrible', 'Baron Von Sheldgoose'),
#  ('Leopard Men', 'Queen La'),
#  ('Leopard Men', 'Kaj'),
#  ('Leopard Men', 'Queen La'),
#  ('Leopard Men', 'Queen La'),
#  ('Leopard Men', 'Kaj'),
#  ('Camille Leon', 'Fashionistas'),
#  ('Camille Leon', 'Dr. Drakken'),
#  ('Camille Leon', 'Camille Chameleon'),
#  ('Shuriki', 'Chancellor Esteban'),
#  ('Shuriki', 'Victor Delgado'),
#  ('Shuriki', 'Carla Delgado'),
#  ('Shuriki', 'Fiero'),
#  ('Shuriki', 'Vestia'),
#  ('Shuriki', 'Troyo'),
#  ('Shuriki', 'Chancellor Esteban'),
#  ('Shuriki', 'Vestia'),
#  ('Shuriki', 'The Evil Queen'),
#  ('Shuriki', 'Chancellor Esteban'),
#  ('Shuriki', 'Victor Delgado'),
#  ('Shuriki', 'Fiero'),
#  ('Shuriki', 'Marimonda'),
#  ('Shuriki', 'Victor Delgado'),
#  ('Shuriki', 'Carla Delgado'),
#  ('Shuriki', 'Marimonda'),
#  ('Shuriki', 'Fiero'),
#  ('Shuriki', 'Ash Delgado'),
#  ('Sylvester Shyster', 'Pete'),
#  ('Sylvester Shyster', 'Pete'),
#  ('LeFou', 'Mr. Smee'),
#  ('LeFou', 'Gaston'),
#  ('LeFou', "Gaston's Buddies"),
#  ('LeFou', 'Gaston'),
#  ('LeFou', "Gaston's Buddies"),
#  ('LeFou', 'Jafar'),
#  ('LeFou', 'Hades'),
#  ('LeFou', 'Mr. Smee'),
#  ('LeFou', 'Gaston'),
#  ('Leech (Goof Troop)', 'Pete'),
#  ('Leech (Goof Troop)', 'Duke (Goof Troop)'),
#  ('Leech', 'Grimsley'),
#  ('Leech', 'Grimsley'),
#  ('Leaf Monster', 'Hildy Gloom'),
#  ('Si and Am', 'Jafar'),
#  ('Si and Am', 'Maleficent'),
#  ('Lea', 'Organization XIII'),
#  ('Lea', 'Roxas'),
#  ('Lea', 'Organization XIII'),
#  ('Lea', 'Heartless'),
#  ('Lea', 'Roxas'),
#  ('Lea', 'Riku'),
#  ('Lea', 'Xemnas'),
#  ('Lea', 'Riku'),
#  ('Lea', 'Roxas'),
#  ('Lea', 'Heartless'),
#  ('Lea', 'Maleficent'),
#  ('Lea', 'Pete'),
#  ('Leroy', 'Leroy Clones'),
#  ('Leroy', 'Captain Gantu'),
#  ('Leroy', 'Leroy Clones'),
#  ('Leroy', 'Leroy Clones'),
#  ('Leroy', 'Captain Gantu'),
#  ('Leroy', 'Leroy Clones'),
#  ('Leroy', 'Leroy Clones'),
#  ('Joka', 'Kaa'),
#  ('Theodora the Wicked Witch of the West',
#   'Evanora the Wicked Witch of the East'),
#  ('Theodora the Wicked Witch of the West',
#   'Evanora the Wicked Witch of the East'),
#  ('Theodora the Wicked Witch of the West',
#   'Evanora the Wicked Witch of the East'),
#  ('Theodora the Wicked Witch of the West', 'Winged Baboons'),
#  ('Theodora the Wicked Witch of the West', 'Queen of Hearts'),
#  ('Theodora the Wicked Witch of the West', 'Rumplestiltskin'),
#  ('Theodora the Wicked Witch of the West', 'Hades'),
#  ('Theodora the Wicked Witch of the West', 'The Evil Queen'),
#  ('Theodora the Wicked Witch of the West', 'Queen of Hearts'),
#  ('Theodora the Wicked Witch of the West', 'Captain Hook'),
#  ('Theodora the Wicked Witch of the West', 'Ingrid'),
#  ('Theodora the Wicked Witch of the West', 'Isaac Heller'),
#  ('Theodora the Wicked Witch of the West', 'Black Fairy'),
#  ('Theodora the Wicked Witch of the West', 'Drizella Tremaine'),
#  ('Theodora the Wicked Witch of the West', 'The Evil Queen'),
#  ('Theodora the Wicked Witch of the West', 'Lady Tremaine'),
#  ('Theodora the Wicked Witch of the West', 'Heinz Doofenshmirtz'),
#  ('Theodora the Wicked Witch of the West', 'Pete'),
#  ('Henchmaniacs', 'Bill Cipher'),
#  ('Henchmaniacs', 'Eye-Bats'),
#  ('Henchmaniacs', 'Bill Cipher'),
#  ('Henchmaniacs', 'Bill Cipher'),
#  ('Jack Hench', 'Professor Dementor'),
#  ('Erik Hellstrom', 'Audrey Ramirez'),
#  ('Reed Thimple', 'Rip Holland'),
#  ('Reed Thimple', 'Rip Holland'),
#  ('Reed Thimple', 'Rip Holland'),
#  ('Helius Inflato', 'Kingpin'),
#  ('Lana Thomas', 'Josh Bryant'),
#  ('Lana Thomas', 'Josh Bryant'),
#  ("Heinz Doofenshmirtz's mother", "Heinz Doofenshmirtz's father"),
#  ("Heinz Doofenshmirtz's mother", 'Heinz Doofenshmirtz'),
#  ("Heinz Doofenshmirtz's mother", 'Heinz Doofenshmirtz'),
#  ('Hazel Swearengen', 'Gladys'),
#  ('Heffalumps', 'Woozles'),
#  ('Heffalumps', 'Woozles'),
#  ('Heffalumps', 'Skullasaurus'),
#  ('King Hector', 'Chancellor Esteban'),
#  ('King Hector', 'Four Shades of Awesome'),
#  ('King Hector', 'Cedric the Sorcerer'),
#  ('Hector (Tangled)', 'Cassandra (Tangled)'),
#  ('Hector (Tangled)', 'Zhan Tiri'),
#  ('Hector (Tangled)', 'Zhan Tiri'),
#  ('Hecate', 'Canis and Lupus'),
#  ('Hecate', 'Hades'),
#  ('Hecate', 'Pain and Panic'),
#  ('Hecate', 'Hades'),
#  ('Hecate', 'Hades'),
#  ('Heather Collins', 'Karl Fink'),
#  ('Atticus Thorn', 'Madame Leota'),
#  ('The Headless Horseman', 'Queen of Hearts'),
#  ('Hayabusa the Falcon', 'Hun Army'),
#  ('Hayabusa the Falcon', 'Shan Yu'),
#  ('Hayabusa the Falcon', 'Shan Yu'),
#  ('Hayabusa the Falcon', 'Hun Army'),
#  ('Hayabusa the Falcon', 'Shan Yu'),
#  ('Hayabusa the Falcon', 'Elite Hun Soldiers'),
#  ('Hayabusa the Falcon', 'Shan Yu'),
#  ('Hayabusa the Falcon', 'Diablo'),
#  ('Hayabusa the Falcon', 'Iago'),
#  ('Hayabusa the Falcon', 'Diablo'),
#  ('Hayabusa the Falcon', 'Diablo'),
#  ('Alonzo Hawk', 'John Slade'),
#  ('Alonzo Hawk', 'J. J. Wagstaff'),
#  ('Lord Hater', 'Captain Tim'),
#  ('Lord Hater', 'Commander Peepers'),
#  ('Lord Hater', 'Watchdogs'),
#  ('Lord Hater', 'Major Threat'),
#  ('Lord Hater', 'Watchdogs'),
#  ('Lord Hater', 'Emperor Awesome'),
#  ('Lord Hater', 'Lord Dominator'),
#  ('Lord Hater', 'The Black Cube of Darkness'),
#  ('Lord Hater', 'Dr. Screwball Jones'),
#  ('Lord Hater', 'Kragthar'),
#  ('Lord Hater', 'Mandrake the Malfeasant'),
#  ('Lord Hater', 'Little Bits'),
#  ('Lord Hater', 'Gentleman Tooth'),
#  ('Lord Hater', 'Knight Mare'),
#  ('Lord Hater', 'Night Mayor'),
#  ('Lord Hater', 'Lord Dominator'),
#  ('Lord Hater', 'Lord Dominator'),
#  ('Lord Hater', 'Watchdogs'),
#  ('Lord Hater', 'Emperor Awesome'),
#  ('Lord Hater', 'Lord Dominator'),
#  ('Miss Hatchet', 'Monkey Fist'),
#  ('Bree Henderson', 'Chase Henderson'),
#  ('Bree Henderson', 'Adam Henderson'),
#  ('King Henry', 'Maleficent'),
#  ('King Henry', 'Maleficent'),
#  ('Horned King', 'Arawn'),
#  ('Horned King', 'Creeper'),
#  ('Horned King', 'Gwythaints'),
#  ('Horned King', 'Talyllyn'),
#  ('Horned King', 'Creeper'),
#  ('Horned King', 'The Black Cauldron (object)'),
#  ('Horned King', 'The Black Cauldron (object)'),
#  ('Horned King', 'Cauldron Born'),
#  ('Horned King', 'Creeper'),
#  ('Horned King', "Horned King's Guards"),
#  ('Horned King', 'Gwythaints'),
#  ('Horned King', 'Cauldron Born'),
#  ('Horned King', 'Maleficent'),
#  ('Horned King', 'Chernabog'),
#  ('Horned King', 'Creeper'),
#  ('Horned King', 'Gwythaints'),
#  ('Horned King', 'Cauldron Born'),
#  ('Horned King', 'Lord Hater'),
#  ('Horned King', 'Emperor Belos'),
#  ('Horned King', 'Maleficent'),
#  ('Horace (Kick Buttowski)', 'Pantsy'),
#  ('The Mistress of Evil', 'Maleficent'),
#  ('The Mistress of Evil', 'Maleficent'),
#  ('The Mistress of Evil', 'Maleficent'),
#  ('The Mistress of Evil', 'Grandfather Coffin Clock'),
#  ('The Mistress of Evil', 'Captain Gore'),
#  ('The Mistress of Evil', 'Bandito Gang'),
#  ('Harry Hook', 'Uma'),
#  ('Harry Hook', 'Captain Hook'),
#  ('Harry Hook', 'CJ Hook'),
#  ('Harry Hook', 'Captain Hook'),
#  ('Harry Hook', 'CJ Hook'),
#  ('Harry Hook', 'Gil (Descendants)'),
#  ('Hook Hand Pirate', 'Captain Hook'),
#  ('Hook Hand Pirate', 'Blackbeard'),
#  ('Hook Hand Pirate', 'The Crew of the Wicked Wench'),
#  ('Hook Hand Pirate', 'The Crew of the Wicked Wench'),
#  ('Hook Hand Pirate', 'Captain Hook'),
#  ('Hook Hand Pirate', 'Mr. Smee'),
#  ('Hook Hand Pirate', 'Auctioneer'),
#  ('Hook Hand Pirate', 'Redd'),
#  ('Hook Hand Ghost', 'Shackles Jack'),
#  ('Hook Hand Ghost', 'Shackles Jack'),
#  ('Hook Hand Ghost', 'Shackles Jack'),
#  ('Hook Hand Ghost', 'Chain Gang Chuck'),
#  ('Hook Hand Ghost', 'Peg Leg Pat'),
#  ('Hoof and Mouth', 'Hammerhead Hannigan'),
#  ('Hoof and Mouth', 'Hammerhead Hannigan'),
#  ('Honest John', 'The Coachman'),
#  ('Honest John', 'Gideon (Pinocchio)'),
#  ('Honest John', 'Gideon (Pinocchio)'),
#  ('Honest John', 'Gideon (Pinocchio)'),
#  ('Honest John', 'Pete'),
#  ('Honest John', 'The Coachman'),
#  ('Honest John', 'Rumplestiltskin'),
#  ('Honest John', 'Prince John'),
#  ('Constance Hatchaway', 'Hatbox Ghost'),
#  ('Constance Hatchaway', 'Madame Leota'),
#  ('Constance Hatchaway', 'Dr. Facilier'),
#  ('Constance Hatchaway', 'Hatbox Ghost'),
#  ('Constance Hatchaway', 'Madame Leota'),
#  ('Constance Hatchaway', 'Harrison Hightower III'),
#  ('Constance Hatchaway', 'Redd'),
#  ('Hoagy', 'Dr. Terminus'),
#  ('Hoagy', 'The Gogans'),
#  ('Hoagy', 'Dr. Terminus'),
#  ('Hoagy', 'The Gogans'),
#  ('The Sinister 11', 'Dracula'),
#  ('The Sinister 11', 'Dracula'),
#  ('The Sinister 11', 'Constance Hatchaway'),
#  ('The Sinister 11', 'Bluebeard'),
#  ('Hitchhiking Ghosts', 'Cruella De Vil'),
#  ('Hitchhiking Ghosts', 'Pete'),
#  ('Hitchhiking Ghosts', 'Pete'),
#  ('Hitchhiking Ghosts', 'Hatbox Ghost'),
#  ('Hitchhiking Ghosts', 'Skeletons'),
#  ('Hitchhiking Ghosts', 'Pete'),
#  ('Hitchhiking Ghosts', 'Madame Leota'),
#  ('Hitchhiking Ghosts', 'Captain Gore'),
#  ('Hitchhiking Ghosts', 'Hatbox Ghost'),
#  ('Hista', 'Kaa'),
#  ('Sir Hiss', 'Prince John'),
#  ('Sir Hiss', 'Prince John'),
#  ('Sir Hiss', 'Prince John'),
#  ('Sir Hiss', 'Kaa'),
#  ('Sir Hiss', 'Sheriff of Nottingham'),
#  ('Sir Hiss', 'Kaa'),
#  ('Sir Hiss', 'Kaa'),
#  ('Harrison Hightower III', 'Shiriki Utundu'),
#  ('Harrison Hightower III', 'Yeti'),
#  ('Harrison Hightower III', 'Constance Hatchaway'),
#  ('Harrison Hightower III', 'Shiriki Utundu'),
#  ('Harrison Hightower III', 'Yeti'),
#  ('Harrison Hightower III', 'Constance Hatchaway'),
#  ('High Voltage', 'Di Amara'),
#  ('High Voltage', 'Di Amara'),
#  ('The High Command', 'Ammonia Pine'),
#  ('The High Command', 'F.O.W.L.'),
#  ('The High Command', 'Board of Directors'),
#  ('HEX', 'Bots'),
#  ('The Hermit', 'Jafar'),
#  ("Horned King's Guards", 'Horned King'),
#  ("Horned King's Guards", 'Horned King'),
#  ("Horned King's Guards", 'Creeper'),
#  ("Horned King's Guards", 'Horned King'),
#  ("Horned King's Guards", 'Horned King'),
#  ('Hatbox Ghost', 'Constance Hatchaway'),
#  ('Hatbox Ghost', 'Hitchhiking Ghosts'),
#  ('Hatbox Ghost', 'Pete'),
#  ('Hatbox Ghost', 'Madame Leota'),
#  ('Hatbox Ghost', 'Hitchhiking Ghosts'),
#  ('Hatbox Ghost', "Br'er Fox"),
#  ('Hassansins', 'Nizam'),
#  ('Hassansins', 'Nizam'),
#  ('Gustav the Giant', 'Willie the Giant'),
#  ('Gunner', "Blackbeard's Zombie Officers"),
#  ('Gunner', 'Blackbeard'),
#  ('Gunner', 'Blackbeard'),
#  ('Gunner', 'Blackbeard'),
#  ('Gunner', 'Quartermaster'),
#  ('Gumbo', 'Jambalaya Jake'),
#  ('Gumbo', 'Jambalaya Jake'),
#  ('Gumbo', 'Jambalaya Jake'),
#  ('Mrs. Grumplestock', 'Eli Excelsior Pandarus'),
#  ('Tiger (Swiss Family Robinson)', 'Kuala'),
#  ('Tiger (Swiss Family Robinson)', 'Pirates (Swiss Family Robinson)'),
#  ('Tiger (Swiss Family Robinson)', 'Kuala'),
#  ('Tiger (Swiss Family Robinson)', 'Pirates (Swiss Family Robinson)'),
#  ('Ringmaster (Goof Troop)', 'Pete'),
#  ('Ringmaster (Goof Troop)', 'Pete'),
#  ('Time', 'Red Queen'),
#  ('Time', 'Red Queen'),
#  ('Time', 'Red Queen'),
#  ('Time', 'Knave of Hearts'),
#  ('Grotta', 'Cedric the Sorcerer'),
#  ('Grotta', 'Cedric the Sorcerer'),
#  ('Grotta', 'Cedric the Sorcerer'),
#  ('Grotta', 'Princess Ivy'),
#  ('Professor Ichabod Grogg', 'The Dominion'),
#  ('Abigail Timmons', 'Lexi Reed'),
#  ('Abigail Timmons', 'Lexi Reed'),
#  ('Grimtrix', 'Cedric the Sorcerer'),
#  ('Grimtrix', 'Baron Von Rocha'),
#  ...]

# %%
# Make a network
villians_network = nx.DiGraph()

# Add egdes
villians_network.add_edges_from(links)

# Discard isolated nodes
villians_network.remove_nodes_from(list(nx.isolates(villians_network)))

# %%
# Extract the giant connected component
gcc = villians_network.subgraph(max(nx.weakly_connected_components(villians_network), key=len))

# %%
nodes = len(gcc.nodes)

# %%
nodes
# Out:
# 1601

# %%
edges = len(gcc.edges)

# %%
edges
# Out:
# 6112

# %%
top_indegree = sorted(dict(gcc.in_degree()).items(), key=lambda item: item[1], reverse=True)
top_indegree[:5]
# Out:
# [('Captain Hook', 81),
#  ('Pete', 73),
#  ('Maleficent', 71),
#  ('Hades', 63),
#  ('Galactic Empire', 61)]

# %%
top_outdegree = sorted(dict(gcc.out_degree()).items(), key=lambda item: item[1], reverse=True)
top_outdegree[:5]
# Out:
# [('The Overtakers', 40),
#  ('Captain Hook', 34),
#  ('Maleficent', 31),
#  ('Cruella De Vil', 31),
#  ('Hades', 30)]

# %%
# Plotting the in-degree distribution
degree = sorted([d for n, d in gcc.in_degree()])
degree_count = collections.Counter(degree)
deg, count = zip(*degree_count.items())

# With linear axes
plt.figure(figsize=(12,5))
plt.bar(deg, count, width=0.7, color="grey")
plt.title("In Degree Distribution (Linear)")
plt.ylabel("Frequency")
plt.xlabel("Degree")
plt.legend(['In-degree'])

plt.show()

# %%
# Plotting the out-degree distribution
degree = sorted([d for n, d in gcc.out_degree()])
degree_count = collections.Counter(degree)
deg, count = zip(*degree_count.items())

# With linear axes
plt.figure(figsize=(12,5))
plt.bar(deg, count, width=0.7, color="grey")
plt.title("Out Degree Distribution (Linear)")
plt.ylabel("Frequency")
plt.xlabel("Degree")
plt.legend(['Out-degree'])

plt.show()

# %%
# Get node positions based on the Force Atlas 2 algorithm
forceatlas2 = ForceAtlas2(
                          # Behavior alternatives
                          outboundAttractionDistribution=False,  # Dissuade hubs
                          edgeWeightInfluence=0.5,
                          # Performance
                          jitterTolerance=0.2, # Tolerance
                          barnesHutOptimize=True,
                          barnesHutTheta=0.6,
                          # Tuning
                          scalingRatio=5.0,
                          strongGravityMode=True,
                          gravity=1,
                          # Log
                          verbose=False)

# %%
gcc_undirected = gcc.to_undirected()

# %%
degrees = [val for node,val in gcc_undirected.degree()]

# Scale node size according to degree
node_size = [i * 1.6 for i in degrees]

# %%
# Get color nodes according to the universe
marvel_df = df_villains.loc[(df_villains['Universe'] == 'Marvel')]
star_wars_df = df_villains.loc[(df_villains['Universe'] == 'Star Wars')]
pixar_df = df_villains.loc[(df_villains['Universe'] == 'Pixar')]
disney_df = df_villains.loc[(df_villains['Universe'] == 'Disney')]
unkown_df = df_villains.loc[(df_villains['Universe'] == 'N/A')]

color_roles = []
for node in gcc_undirected.nodes():
    if node in marvel_df.name_of_villains.values:
        color_roles.append('#00FF00')
    elif node in star_wars_df.name_of_villains.values:
        color_roles.append('#FF0000')
    elif node in pixar_df.name_of_villains.values:
        color_roles.append('#000000')
    elif node in disney_df.name_of_villains.values:
        color_roles.append('#04D8B2')
    elif node in unkown_df.name_of_villains.values:
        color_roles.append('#FF7F50')

# %%
edge_colors = []
for u, v in gcc_undirected.edges():
    edge_colors.append("#C0C0C0")

# %%
f = plt.figure(figsize=(16,16))
ax = plt.gca()

# Create a legend for the different colors
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Marvel',
                          markerfacecolor="#00FF00", markersize=10, alpha=0.6),
                   Line2D([0], [0], marker='o', color='w', label='Star Wars',
                          markerfacecolor="#FF0000", markersize=10, alpha=0.6),
                   Line2D([0], [0], marker='o', color='w', label='Pixar',
                          markerfacecolor="#000000", markersize=10, alpha=0.6),
                   Line2D([0], [0], marker='o', color='w', label='Disney',
                          markerfacecolor="#04D8B2", markersize=10, alpha=0.6),
                   Line2D([0], [0], marker='o', color='w', label='N/A',
                          markerfacecolor="#FF7F50", markersize=10, alpha=0.6),
                   Line2D([0], [0], color="#C0C0C0", label='Edges')]

positions = forceatlas2.forceatlas2_networkx_layout(gcc_undirected, pos=None, iterations=50)
nodes = nx.draw_networkx_nodes(gcc_undirected, positions, node_size=node_size, node_color=color_roles, alpha=0.7)
edges = nx.draw_networkx_edges(gcc_undirected, positions, edge_color=edge_colors,alpha=0.7)

plt.axis('off')
plt.title("Giant Connected Component of the Villains network", fontsize=16)

plt.legend(handles=legend_elements, facecolor='white', framealpha=1)

plt.show()

# %%
# add attributes to the nodes of gcc_undirected

# 1. create dictionary from df_villains dataframe
node_attr = df_villains.set_index('name_of_villains').to_dict('index')
nx.set_node_attributes(gcc_undirected, node_attr)

# %%
gcc_undirected.nodes['Toon'] # now each node has attribute of universe
# Out:
# {'Universe': 'Disney'}

# %% [markdown]
# #### We will figure out which edges connect villains from different universes

# %%
# We don't take into account characters thet are not assigned in any of our four main universes
list_miltiverse = []
for u, v in gcc_undirected.edges():
    role_u = gcc_undirected.nodes[u]['Universe']
    role_v = gcc_undirected.nodes[v]['Universe']
    if role_u == 'N/A':
        continue
    elif role_v == 'N/A':
        continue
    else:
        if role_u != role_v:
            list_miltiverse.append((u,v))
        else:
            continue

# %%
len(list_miltiverse)
# Out:
# 118

# %% [markdown]
# These are all the edges connecting characters from different universes

# %%
list_miltiverse
# Out:
# [('Felicia', 'Jabba the Hutt'),
#  ('Captain Hook', 'Randall Boggs'),
#  ('Captain Hook', 'Doctor Doom'),
#  ('Captain Hook', 'President Loki'),
#  ('Captain Hook', 'Ercole Visconti'),
#  ('Scar', 'Hopper'),
#  ('Scar', 'Darth Vader'),
#  ('Hades', 'Hydra'),
#  ('Hades', "Lots-o'-Huggin' Bear"),
#  ('Hades', 'Big Baby'),
#  ('Gaston', 'Ercole Visconti'),
#  ('Duff Killigan', 'Darth Vader'),
#  ('Mandarin', 'Eric Savin'),
#  ('Maleficent', 'Dragons'),
#  ('Maleficent', 'Miss Fritter'),
#  ('Lord Dragaunus', 'Dragons'),
#  ('Davy Jones', 'Jabba the Hutt'),
#  ('Khaka Peu Peu', 'Green Goblin'),
#  ('Green Goblin', 'Creeper'),
#  ('Lord Dominator', 'Darth Vader'),
#  ('Lyle Tiberius Rourke', "Lots-o'-Huggin' Bear"),
#  ('Lyle Tiberius Rourke', 'Miles Axlerod'),
#  ('Lyle Tiberius Rourke', 'Ernesto de la Cruz'),
#  ('Jabberwocky (2010)', 'Dragons'),
#  ('The Evil Queen', 'Palpatine'),
#  ('The Evil Queen', "Frankenstein's Monster"),
#  ('Julius', "Frankenstein's Monster"),
#  ('Pete', 'Jango Fett'),
#  ('The Collector', 'Collector'),
#  ('Cruella De Vil', 'Dracula'),
#  ('Megavolt', 'Electro'),
#  ('Skeletons', 'Grim Reaper'),
#  ('The Grim Reaper', 'Grim Reaper'),
#  ('The Grim Reaper', 'Hela'),
#  ('Kazar', 'Hopper'),
#  ('Heinz Doofenshmirtz', 'Emperor Zurg'),
#  ('Heinz Doofenshmirtz', 'Venom'),
#  ('Heinz Doofenshmirtz', 'Red Skull'),
#  ('Heinz Doofenshmirtz', 'M.O.D.O.K.'),
#  ('Mr. Wesley', 'Randall Boggs'),
#  ('Loki (Hercules)', 'Loki Laufeyson'),
#  ('Liquidator', 'Hydro-Man'),
#  ('Nuka', 'Velociraptors (The Good Dinosaur)'),
#  ('Toffee', 'Magneto'),
#  ('Erwin Lawson', 'Sid Phillips'),
#  ('Sid Phillips', 'Josh Bryant'),
#  ('Sierra McCool', 'Ercole Visconti'),
#  ('L.O.V.E.M.U.F.F.I.N.', 'Venom'),
#  ('Morgana le Fay', 'Morgan le Fay'),
#  ('Leroy Clones', 'Clone Troopers'),
#  ('Xemnas', 'Ultron-Sigma'),
#  ('Helius Inflato', 'Kingpin'),
#  ('Gwythaints', 'Dragons'),
#  ('The Sinister 11', 'Dracula'),
#  ('Dracula', 'Phantom Blot'),
#  ('Dracula', 'Bluebeard'),
#  ('Yeti', 'Collector'),
#  ('Hydra', 'Dragons'),
#  ('Mal', 'Dragons'),
#  ('Yzma', 'Randall Boggs'),
#  ('Thunder Jack', 'Henry J. Waternoose III'),
#  ('Henry J. Waternoose III', 'Bellwether'),
#  ('Jackal', 'Jackal (Marvel)'),
#  ('Dr. Jekyll', 'Calvin Zabo'),
#  ('Phantom Blot', 'Darth Vader'),
#  ('Phantom Blot', 'Doctor Doom'),
#  ('Thailog', 'Emperor Zurg'),
#  ('Emperor Zurg', 'Darth Vader'),
#  ('Emperor Zurg', 'Galactic Empire'),
#  ('Hunter De Vil', 'Agent Kallus'),
#  ('Dragons', 'Asteroth'),
#  ('Dragons', 'Jabberwocky (1951)'),
#  ('Dragons', 'Madam Mim'),
#  ('Dragons', 'Malcho'),
#  ('Dragons', 'Memnon'),
#  ('Dragons', 'Pixiu'),
#  ('Dragons', 'Queen Narissa'),
#  ('Dragons', 'The Dark Dragon'),
#  ('Dragons', 'The Dragon (Jake and the Never Land Pirates)'),
#  ('Dragons', 'Vermithrax Pejorative'),
#  ('CLU 2.0', 'Bucky Barnes'),
#  ('Victor Krane', 'Palpatine'),
#  ('Victor Krane', 'Darth Vader'),
#  ('Sentry Robots', 'Darth Vader'),
#  ('Zarina', 'Gabby Gabby'),
#  ('Oogie Boogie', 'Vampires'),
#  ('Oogie Boogie', 'Agatha Harkness'),
#  ('Vanitas', 'Randall Boggs'),
#  ('Sand Monster', 'Sandman'),
#  ('Rinzler', 'Bucky Barnes'),
#  ('Ripslinger', 'Chick Hicks'),
#  ('Chick Hicks', 'Trip Murphy'),
#  ("Lots-o'-Huggin' Bear", 'Darth Vader'),
#  ("Lots-o'-Huggin' Bear", 'Palpatine'),
#  ("Lots-o'-Huggin' Bear", 'First Order Stormtroopers'),
#  ('Darth Vader', 'Big Baby'),
#  ('Darth Vader', 'Tuskerninni'),
#  ('Darth Vader', 'The Cleric'),
#  ('Randall Weems', 'Randall Boggs'),
#  ('Randall Boggs', 'Unversed'),
#  ('Randall Boggs', 'Wacky Weasel'),
#  ('Palpatine', 'Big Baby'),
#  ('Palpatine', 'The Cleric'),
#  ('Vulture', 'Venom'),
#  ('Vulture', 'Scorpion'),
#  ('Wreck Marauder', 'Venom'),
#  ('Venom', 'Ravana'),
#  ('Toy Duck', 'Vampires'),
#  ('Nazis', 'Colonel Heller'),
#  ('Nazis', 'Little Hans'),
#  ('Nazis', 'First Order'),
#  ('Nazis', 'Galactic Empire'),
#  ('Bucky Barnes', 'Warp Darkmatter'),
#  ('Nebula', 'XL'),
#  ('Beetle', 'Boba Fett'),
#  ('Mesmero', 'Mezmerella'),
#  ('Boba Fett', 'Shiv Katall'),
#  ('Hornets', 'Battle Droids')]

# %% [markdown]
# we see the characters with the most connections to other universes

# %%
from collections import Counter
out = [item for t in list_miltiverse for item in t]
x=collections.Counter(out)
print(x.most_common(10))
# Out:
# [('Dragons', 16), ('Darth Vader', 11), ('Randall Boggs', 7), ("Lots-o'-Huggin' Bear", 5), ('Palpatine', 5), ('Venom', 5), ('Captain Hook', 4), ('Dracula', 4), ('Heinz Doofenshmirtz', 4), ('Emperor Zurg', 4)]

# %% [markdown]
# ## NOTE!

# %% [markdown]
# We have dragons and The Overtakers in the dataset (they are group of characters) I think they should be deleted. It can be done manually with no problem

# %%
def get_quotes(df_villains):
    script_path = os.getcwd()
    folder = 'Villains2/'
    path = os.path.join(script_path,folder)
    
    quotes_pattern = '\{\{Quote\|(.*?)[\[\[(.*?)\]\]]?(?:\|.*?)\}\}'

    
    quotes = []
    for char in df_villains.name_of_villains.values:
        # open the description files
        with open(path + char + '.txt', 'r') as f:
            node_description = f.read()
        
        find_quotes = re.findall(quotes_pattern, node_description)
            
        for q in find_quotes:
            quotes.append((char, q))

    return quotes

# %%
quotes = get_universe(df_villains)

# %% [markdown]
# ### Tools, theory and analysis <a class="anchor" id="chapter3"></a>

# %% [markdown]
# ### Discussion <a class="anchor" id="chapter4"></a>

# %% [markdown]
# ### Contributions <a class="anchor" id="chapter5"></a>
